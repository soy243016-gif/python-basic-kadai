# %%
# 消費税を加えた金額を計算する関数
def calculate_total(price, tax):
    return price * (1 + tax / 100)

# 商品価格と消費税率
price = 110
tax = 10

# 関数を呼び出して結果を表示
print(calculate_total(price, tax))
# Out:
# 121.00000000000001
