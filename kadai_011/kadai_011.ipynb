# %%
# forループ whileループの順で「水～冥」を表示

array = ["水","金","地","火","木","土","天","海","冥"]

# --- forループ ---
for planet in array:
    print(planet)

# --- whileループ ---
i = 0
while i < len(array):
    print(array[i])
    i += 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
